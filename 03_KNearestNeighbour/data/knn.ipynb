# %%
import pandas as pd

dataset = pd.read_csv("./breast_cancer.csv")
dataset.head(5)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    object
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
# ...

# %% [markdown]
# dropping the unused columns

# %%
dataset.drop(columns=['id', 'Unnamed: 32'], inplace=True)
dataset.sample(5)
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 137         B        11.43         15.39           73.06      399.8
# 406         B        16.14         14.86          104.30      800.0
# 448         B        14.53         19.34           94.25      659.7
# 57          M        14.71         21.59           95.55      656.9
# 117         M        14.87         16.67           98.64      682.5
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 137          0.09639           0.06889         0.03503              0.02875
# 406          0.09495           0.08501         0.05500              0.04528
# 448          0.08388           0.07800         0.08817              0.02925
# 57           0.11370           0.13650         0.12930              0.08123
# 117          0.11620           0.16490         0.16900              0.08923
#
#      symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
from sklearn.model_selection import train_test_split

X = dataset.iloc[:, 1:]
y = dataset.iloc[:, 0]  
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %% [markdown]
# converting values for same scale - because knn rely in distances

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train
# Out:
# array([[-0.01330339,  1.7757658 , -0.01491962, ..., -0.13236958,
#         -1.08014517, -0.03527943],
#        [-0.8448276 , -0.6284278 , -0.87702746, ..., -1.11552632,
#         -0.85773964, -0.72098905],
#        [ 1.44755936,  0.71180168,  1.47428816, ...,  0.87583964,
#          0.4967602 ,  0.46321706],
#        ...,
#        [-0.46608541, -1.49375484, -0.53234924, ..., -1.32388956,
#         -1.02997851, -0.75145272],
#        [-0.50025764, -1.62161319, -0.527814  , ..., -0.0987626 ,
#          0.35796577, -0.43906159],
#        [ 0.96060511,  1.21181916,  1.00427242, ...,  0.8956983 ,
#         -1.23064515,  0.50697397]])

# %%
X_train.shape
# Out:
# (455, 30)

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
from sklearn.metrics import accuracy_score


y_pred = knn.predict(X_test)

score = accuracy_score(y_test, y_pred)
score
# Out:
# 0.9736842105263158

# %% [markdown]
# ### Steps
#
# - read data
# - drop columns that are not important
# - split into train test
# - standardize values

# %% [markdown]
# # Interview Questions from this topic

# %% [markdown]
# 1. how does knn works?
#
# 2. what is the meaning of random_state parameter?
#    <br> When you split data into training and testing sets, the process involves randomly selecting samples.
#    <br> Without a random_state, this randomness can lead to different splits each time you run the code.
# <br>
#
# 3. why do we need to standardize value?
#
# <br>
#
# 4. why use fit_transform in X_train and transform in X_test?
#
# <br>
#
# 5. how to select the value of k?
#    <br> It depends on you dataset, however we have two approached.
#    <br>    - **Experimentations**, where you take k from 1 to 25 for training and find the best accuracy score value.
#    <br>    - **Heuristic Approach**, where you take square-root of n {n: no of observations}, but you also avoid even value of k.
#
# <br>
#
# 6. what are the limitations of knn?
#    <br>  - large datasets, because it is a lazy learning algorithm (we do nothing on training phase all calculation happeds as prediction phase)
#    <br>  - high dimensional data, because curse of dimentsionality occurs
#    <br>  - outliers, when you have noise in data (it'll cause wrong predictions)
#    <br>  - imbalanced dataset, only if difference is huge
#    <br>  - It is good in prediction not in inferencing, because it is a black box model, we don't know which feature is important.
#
# <br><br>
#
# 7. what is curse of dimensionality?
#    <br> it is a rule that says, taking distance in higher dimensions is not reliable approach
